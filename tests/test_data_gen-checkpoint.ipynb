# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")
from data.gmm_gen import GMMDataGen
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# ### 1d test

# %%
generator = GMMDataGen(d=1, C=20)
sampler = generator.sampler(10000)

# %%
samples = []
for sample in sampler:
    samples.append(sample)

# %%
plt.hist(samples, bins=50)
plt.title("Distribution of the GMM samples")
plt.show()

# %% [markdown]
# ### 2d test

# %%
generator = GMMDataGen(d=2, C=10, radius=50)
sampler = generator.sampler(100000)

# %%
samples = []
for sample in sampler:
    samples.append(sample)
samples = np.array(samples)

# %%
fig, ax = plt.subplots(figsize=(7, 7))
ax.scatter(samples[:, 0], samples[:, 1])
ax.set_title('Samples from the 2d GMM')

xyMIN = -60
xyMAX = 60

ax.set_xlim(xyMIN, xyMAX)
ax.set_ylim(xyMIN, xyMAX)
plt.show()
